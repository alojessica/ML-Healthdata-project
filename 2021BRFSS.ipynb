# %%
import pandas as pd

data = pd.read_csv('LLCP2021.ASC') 

data.head(10).T
# Out:
#                                                                                                     0  \
# 01              0101192021     11002021000001  ...  01              0101212021     11002021000002 ...
#
#                                                                                                     1  \
# 01              0101192021     11002021000001  ...  01              0101212021     11002021000003 ...
#
#                                                                                                     2  \
# 01              0101192021     11002021000001  ...  01              0101172021     11002021000004 ...
#
#                                                                                                     3  \
# 01              0101192021     11002021000001  ...  01              0101152021     11002021000005 ...
#
#                                                                                                     4  \
# ...
