# %% [markdown]
# # Research question
#
# - How do different patterns of Adverse Childhood Experiences predict mental health outcomes, and did this relationship change during and post COVID-19 pandemic
#
# **Analyzing**
# - 2018: Pre Covid
#     - [2018 BRFSS](https://www.cdc.gov/brfss/annual_data/annual_2018.html)
#     - [2018 SMART](https://www.cdc.gov/brfss/smart/smart_2018.html)
# - 2021: Covid Year
#     - [2021 BRFSS](https://www.cdc.gov/brfss/annual_data/annual_2021.html)
#     - [2021 SMART](https://www.cdc.gov/brfss/smart/smart_2021.html)
# - 2023: Post Covid
#     - [2023 BRFSS](https://www.cdc.gov/brfss/annual_data/annual_2023.html)
#     - [2023 SMART](https://www.cdc.gov/brfss/smart/smart_2023.html)
#
# **Data sets**
# - BRFSS: Behavioral Risk Factor Surveillance System
#     - nation’s premier system of health-related telephone surveys that collect state data about U.S. residents regarding their health-related risk behaviors, chronic health conditions, and use of preventive services.

# %% [markdown]
# # Timeline
#
# - 10/12: Finish Clenaning data
# - 10/14 -- 10/26: Data Visualize and Analysis
# - 11/16 -- 11/13: Logistic Regression, KNN, KMeans
# - 11/23 -- 11/30: App/Dashboard & Presentation
# - 12/2 -- 12/7: Presentation/Dashboard & MLP
# - 12/9: Presentation practice/ final touches
# - 12/12: Final presntation

# %% [markdown]
# # Models
#
# - Logistic Regression : Randa Ampah and Aysha Hussen
# - KNN: Isabel Delgado and Aniyah McWilliams
# - K-Means: Jessica Oseghale
# - MLP: Jessica Oseghale and Aniyah McWilliams

# %% [markdown]
# # Presentation
#
# - Powerpoint: Everyone
#     - Leads: Jessica Oseghale and Aniyah McWilliams
#
# - Plotlydash: Randa Ampah, Aysha Hussen, Isabel Delgado,
